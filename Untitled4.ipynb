# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhithluck/Capstone-Project/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/bhp.csv')
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
desired_coloumns = ['location', 'price_per_sqft']
df = df[desired_coloumns]
df
# Out:
#                        location  price_per_sqft
# 0      Electronic City Phase II            3699
# 1              Chikka Tirupathi            4615
# 2                   Uttarahalli            4305
# 3            Lingadheeranahalli            6245
# 4                      Kothanur            4250
# ...                         ...             ...
# 13195                Whitefield            6689
# 13196                     other           11111
# 13197     Raja Rajeshwari Nagar            5258
# 13198           Padmanabhanagar           10407
# 13199              Doddathoguru            3090
#
# [13200 rows x 2 columns]

# %%
df.describe()
# Out:
#        price_per_sqft
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07

# %%
lower_bound = df['price_per_sqft'].quantile(0.001)
upper_bound = df['price_per_sqft'].quantile(0.999)

# %%
df_quantile_method = df[(df.price_per_sqft > lower_bound) & (df.price_per_sqft < upper_bound )]
df_quantile_method
# Out:
#                        location  price_per_sqft
# 0      Electronic City Phase II            3699
# 1              Chikka Tirupathi            4615
# 2                   Uttarahalli            4305
# 3            Lingadheeranahalli            6245
# 4                      Kothanur            4250
# ...                         ...             ...
# 13195                Whitefield            6689
# 13196                     other           11111
# 13197     Raja Rajeshwari Nagar            5258
# 13198           Padmanabhanagar           10407
# 13199              Doddathoguru            3090
#
# [13172 rows x 2 columns]

# %%
mean = df.price_per_sqft.mean()
std_deviation = df.price_per_sqft.std()

# %%
lower_limit = mean - 4*std_deviation
upper_limit = mean + 4*std_deviation

# %%
df_std_method = df[(df.price_per_sqft > lower_limit) & (df.price_per_sqft < upper_limit)]
df_std_method
# Out:
#                        location  price_per_sqft
# 0      Electronic City Phase II            3699
# 1              Chikka Tirupathi            4615
# 2                   Uttarahalli            4305
# 3            Lingadheeranahalli            6245
# 4                      Kothanur            4250
# ...                         ...             ...
# 13195                Whitefield            6689
# 13196                     other           11111
# 13197     Raja Rajeshwari Nagar            5258
# 13198           Padmanabhanagar           10407
# 13199              Doddathoguru            3090
#
# [13047 rows x 2 columns]

# %%
import seaborn as sns

sns.histplot(df.price_per_sqft, kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
df_z_score = df_quantile_method.price_per_sqft - df_quantile_method.price_per_sqft.mean() / df_quantile_method.price_per_sqft.std()
df_z_score
# Out:
# 0         3697.390819
# 1         4613.390819
# 2         4303.390819
# 3         6243.390819
# 4         4248.390819
#              ...
# 13195     6687.390819
# 13196    11109.390819
# 13197     5256.390819
# 13198    10405.390819
# 13199     3088.390819
# Name: price_per_sqft, Length: 13172, dtype: float64

# %%
df_quantile_method['z_score'] = z_score
df_quantile_method
# Out:
#                        location  price_per_sqft       z_score
# 0      Electronic City Phase II            3699   3697.390819
# 1              Chikka Tirupathi            4615   4613.390819
# 2                   Uttarahalli            4305   4303.390819
# 3            Lingadheeranahalli            6245   6243.390819
# 4                      Kothanur            4250   4248.390819
# ...                         ...             ...           ...
# 13195                Whitefield            6689   6687.390819
# 13196                     other           11111  11109.390819
# 13197     Raja Rajeshwari Nagar            5258   5256.390819
# 13198           Padmanabhanagar           10407  10405.390819
# 13199              Doddathoguru            3090   3088.390819
#
# [13172 rows x 3 columns]

# %%
outliers = df[(df_quantile_method.z_score > -4) | (df_quantile_method.z_score < 4)]
outliers
# Out:
#                        location  price_per_sqft
# 0      Electronic City Phase II            3699
# 1              Chikka Tirupathi            4615
# 2                   Uttarahalli            4305
# 3            Lingadheeranahalli            6245
# 4                      Kothanur            4250
# ...                         ...             ...
# 13195                Whitefield            6689
# 13196                     other           11111
# 13197     Raja Rajeshwari Nagar            5258
# 13198           Padmanabhanagar           10407
# 13199              Doddathoguru            3090
#
# [13172 rows x 2 columns]

# %%
df_z_score.shape
# Out:
# (0, 2)
